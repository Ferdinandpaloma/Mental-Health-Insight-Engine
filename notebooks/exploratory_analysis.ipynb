# %% [markdown]
# # Exploratory Data Analysis
# ## Campus Mental Health Insight Engine
#
# This notebook performs exploratory data analysis on student mental health data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

# Add src to path
sys.path.append('../src')

from data_preprocessing import DataPreprocessor
from clustering import StudentClustering
from correlation_analysis import CorrelationAnalyzer

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

# Add src to path
sys.path.append('../src')

from data_preprocessing import DataPreprocessor
from clustering import StudentClustering
from correlation_analysis import CorrelationAnalyzer

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# %% [markdown]
# ## 1. Load and Preprocess Data

# %%
# Option 1: Load Kaggle dataset (already adapted)
# First run: python src/adapt_kaggle_data.py
data_path = '../data/processed/kaggle_adapted.csv'

# Option 2: Load raw data and preprocess
# data_path = '../data/raw/student_data.csv'
# preprocessor = DataPreprocessor()
# df = preprocessor.preprocess_pipeline(
#     file_path=data_path,
#     save_path='../data/processed/processed_data.csv'
# )

# Load the adapted/preprocessed data
df = pd.read_csv(data_path)

print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
df.head()
